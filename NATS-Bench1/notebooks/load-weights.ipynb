# %%
import random
import numpy as np
from nats_bench import create
from pprint import pprint
# Create the API for tologoy search space
api = create("../fake_torch_dir/NATS-tss-v1_0-3ffb9-full", 'tss', fast_mode=True, verbose=False)

# %%
dataset = 'cifar10'
index = 531
info = api.get_more_info(531, dataset, hp='200', is_random=False)
config = api.get_net_param(531, 'cifar10', None)
#print(info)
print(config[111].keys())
print((config[111]['cells.0.layers.0.op.1.weight'].shape))
# Out:
# odict_keys(['stem.0.weight', 'stem.1.weight', 'stem.1.bias', 'stem.1.running_mean', 'stem.1.running_var', 'stem.1.num_batches_tracked', 'cells.0.layers.0.op.1.weight', 'cells.0.layers.0.op.2.weight', 'cells.0.layers.0.op.2.bias', 'cells.0.layers.0.op.2.running_mean', 'cells.0.layers.0.op.2.running_var', 'cells.0.layers.0.op.2.num_batches_tracked', 'cells.0.layers.2.op.1.weight', 'cells.0.layers.2.op.2.weight', 'cells.0.layers.2.op.2.bias', 'cells.0.layers.2.op.2.running_mean', 'cells.0.layers.2.op.2.running_var', 'cells.0.layers.2.op.2.num_batches_tracked', 'cells.0.layers.3.op.1.weight', 'cells.0.layers.3.op.2.weight', 'cells.0.layers.3.op.2.bias', 'cells.0.layers.3.op.2.running_mean', 'cells.0.layers.3.op.2.running_var', 'cells.0.layers.3.op.2.num_batches_tracked', 'cells.0.layers.4.op.1.weight', 'cells.0.layers.4.op.2.weight', 'cells.0.layers.4.op.2.bias', 'cells.0.layers.4.op.2.running_mean', 'cells.0.layers.4.op.2.running_var', 'cells.0.layers.4.op.2.num_batches_tracked', 'cells.0.layers.5.op.1.weight', 'cells.0.layers.5.op.2.weight', 'cells.0.layers.5.op.2.bias', 'cells.0.layers.5.op.2.running_mean', 'cells.0.layers.5.op.2.running_var', 'cells.0.layers.5.op.2.num_batches_tracked', 'cells.1.layers.0.op.1.weight', 'cells.1.layers.0.op.2.weight', 'cells.1.layers.0.op.2.bias', 'cells.1.layers.0.op.2.running_mean', 'cells.1.layers.0.op.2.running_var', 'cells.1.layers.0.op.2.num_batches_tracked', 'cells.1.layers.2.op.1.weight', 'cells.1.layers.2.op.2.weight', 'cells.1.layers.2.op.2.bias', 'cells.1.layers.2.op.2.running_mean', 'cells.1.layers.2.op.2.running_var', 'cells.1.layers.2.op.2.num_batches_tracked', 'cells.1.layers.3.op.1.weight', 'cells.1.layers.3.op.2.weight', 'cells.1.layers.3.op.2.bias', 'cells.1.layers.3.op.2.running_mean', 'cells.1.layers.3.op.2.running_var', 'cells.1.layers.3.op.2.num_batches_tracked', 'cells.1.layers.4.op.1.weight', 'cells.1.layers.4.op.2.weight', 'cells.1.layers.4.op.2.bias', 'cells.1.layers.4.op.2.running_mean', 'cells.1.layers.4.op.2.running_var', 'cells.1.layers.4.op.2.num_batches_tracked', 'cells.1.layers.5.op.1.weight', 'cells.1.layers.5.op.2.weight', 'cells.1.layers.5.op.2.bias', 'cells.1.layers.5.op.2.running_mean', 'cells.1.layers.5.op.2.running_var', 'cells.1.layers.5.op.2.num_batches_tracked', 'cells.2.layers.0.op.1.weight', 'cells.2.layers.0.op.2.weight', 'cells.2.layers.0.op.2.bias', 'cells.2.layers.0.op.2.running_mean', 'cells.2.layers.0.op.2.running_var', 'cells.2.layers.0.op.2.num_batches_tracked', 'cells.2.layers.2.op.1.weight', 'cells.2.layers.2.op.2.weight', 'cells.2.layers.2.op.2.bias', 'cells.2.layers.2.op.2.running_mean', 'cells.2.layers.2.op.2.running_var', 'cells.2.layers.2.op.2.num_batches_tracked', 'cells.2.layers.3.op.1.weight', 'cells.2.layers.3.op.2.weight', 'cells.2.layers.3.op.2.bias', 'cells.2.layers.3.op.2.running_mean', 'cells.2.layers.3.op.2.running_var', 'cells.2.layers.3.op.2.num_batches_tracked', 'cells.2.layers.4.op.1.weight', 'cells.2.layers.4.op.2.weight', 'cells.2.layers.4.op.2.bias', 'cells.2.layers.4.op.2.running_mean', 'cells.2.layers.4.op.2.running_var', 'cells.2.layers.4.op.2.num_batches_tracked', 'cells.2.layers.5.op.1.weight', 'cells.2.layers.5.op.2.weight', 'cells.2.layers.5.op.2.bias', 'cells.2.layers.5.op.2.running_mean', 'cells.2.layers.5.op.2.running_var', 'cells.2.layers.5.op.2.num_batches_tracked', 'cells.3.layers.0.op.1.weight', 'cells.3.layers.0.op.2.weight', 'cells.3.layers.0.op.2.bias', 'cells.3.layers.0.op.2.running_mean', 'cells.3.layers.0.op.2.running_var', 'cells.3.layers.0.op.2.num_batches_tracked', 'cells.3.layers.2.op.1.weight', 'cells.3.layers.2.op.2.weight', 'cells.3.layers.2.op.2.bias', 'cells.3.layers.2.op.2.running_mean', 'cells.3.layers.2.op.2.running_var', 'cells.3.layers.2.op.2.num_batches_tracked', 'cells.3.layers.3.op.1.weight', 'cells.3.layers.3.op.2.weight', 'cells.3.layers.3.op.2.bias', 'cells.3.layers.3.op.2.running_mean', 'cells.3.layers.3.op.2.running_var', 'cells.3.layers.3.op.2.num_batches_tracked', 'cells.3.lay ...
# torch.Size([16, 16, 1, 1])
